# %% [markdown]
# ## Game Recommender
#
# by: Jerry Phillips

# %% [markdown]
# ## Background
# As required by the Umass Capstone project this project will attempt to provide Game recommendations off of a generated dataset provided from Kaggle.

# %% [markdown]
# # 1. Install and import the required libraries

# %%
# Install the required library
# !pip install -U scikit-learn
# !pip install kaggle
# Out:
# Requirement already satisfied: scikit-learn in /opt/anaconda3/lib/python3.13/site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in /opt/anaconda3/lib/python3.13/site-packages (from scikit-learn) (2.1.3)
# Requirement already satisfied: scipy>=1.10.0 in /opt/anaconda3/lib/python3.13/site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.3.0 in /opt/anaconda3/lib/python3.13/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: kaggle in /opt/anaconda3/lib/python3.13/site-packages (1.8.3)
# Requirement already satisfied: black>=24.10.0 in /opt/anaconda3/lib/python3.13/site-packages (from kaggle) (24.10.0)
# Requirement already satisfied: bleach in /opt/anaconda3/lib/python3.13/site-packages (from kaggle) (6.2.0)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.14 in /opt/anaconda3/lib/python3.13/site-packages (from kaggle) (0.1.14)
# Requirement already satisfied: mypy>=1.15.0 in /opt/anaconda3/lib/python3.13/site-packages (from kaggle) (1.19.1)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.13/site-packages (from kaggle) (24.2)
# Requirement already satisfied: protobuf in /opt/anaconda3/lib/python3.13/site-packages (from kaggle) (5.29.3)
# Requirement already satisfied: python-dateutil in /opt/anaconda3/lib/python3.13/site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /opt/anaconda3/lib/python3.13/site-packages (from kaggle) (5.0.2)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.13/site-packages (from kaggle) (2.32.3)
# Requirement already satisfied: six>=1.10 in /opt/anaconda3/lib/python3.13/site-packages (from kaggle) (1.17.0)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.13/site-packages (from kaggle) (4.67.1)
# Requirement already satisfied: types-requests in /opt/anaconda3/lib/python3.13/site-packages (from kaggle) (2.32.4.20250913)
# Requirement already satisfied: types-tqdm in /opt/anaconda3/lib/python3.13/site-packages (from kaggle) (4.67.0.20250809)
# Requirement already satisfied: urllib3>=1.15.1 in /opt/anaconda3/lib/python3.13/site-packages (from kaggle) (2.3.0)
# Requirement already satisfied: click>=8.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from black>=24.10.0->kaggle) (8.1.8)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /opt/anaconda3/lib/python3.13/site-packages (from black>=24.10.0->kaggle) (1.0.0)
# Requirement already satisfied: pathspec>=0.9.0 in /opt/anaconda3/lib/python3.13/site-packages (from black>=24.10.0->kaggle) (0.10.3)
# Requirement already satisfied: platformdirs>=2 in /opt/anaconda3/lib/python3.13/site-packages (from black>=24.10.0->kaggle) (4.3.7)
# Requirement already satisfied: typing_extensions>=4.6.0 in /opt/anaconda3/lib/python3.13/site-packages (from mypy>=1.15.0->kaggle) (4.12.2)
# Requirement already satisfied: librt>=0.6.2 in /opt/anaconda3/lib/python3.13/site-packages (from mypy>=1.15.0->kaggle) (0.7.7)
# Requirement already satisfied: webencodings in /opt/anaconda3/lib/python3.13/site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /opt/anaconda3/lib/python3.13/site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.13/site-packages (from requests->kaggle) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.13/site-packages (from requests->kaggle) (2025.11.12)

# %%
import os
import zipfile
import json

# library for data processing
import pandas as pd
import numpy as np
from collections import Counter
from sklearn.preprocessing import MinMaxScaler

# library to make the recommendation system model
from sklearn.neighbors import NearestNeighbors
from sklearn.metrics.pairwise import cosine_similarity

# library for evaluate the machine learning model
from sklearn.metrics import calinski_harabasz_score, davies_bouldin_score

# %% [markdown]
# # 2. Prepares the Dataset

# %% [markdown]
# ### 2.1 Prepare the username and kaggle key

# %%
# prepares the Kaggle credential environment

os.environ['KAGGLE_USERNAME'] = 'jerseid'
os.environ['KAGGLE_KEY'] = 'KGAT_21a1fc6b16960208c03e2fcefe67e219'

# %% [markdown]
# ### 2.2 Download and prepare the dataset

# %%
#!/bin/bash
# !kaggle datasets download jahnavipaliwal/video-game-reviews-and-ratings
# Out:
# Dataset URL: https://www.kaggle.com/datasets/jahnavipaliwal/video-game-reviews-and-ratings
# License(s): apache-2.0
# Downloading video-game-reviews-and-ratings.zip to /Users/jerryphillips/anaconda_projects/f0bafc16-4759-43a0-9709-3792efe4f201
#  91%|██████████████████████████████████▌   | 1.00M/1.10M [00:00<00:00, 2.49MB/s]
# 100%|██████████████████████████████████████| 1.10M/1.10M [00:00<00:00, 2.67MB/s]

# %%
# Extract zip file to CWD
import zipfile

# Define the zip file path
files = "/Users/jerryphillips/Downloads/archive.zip"

# Get the current working directory (which should be writable)
extract_path = os.getcwd()  # This will use the current working directory

# Extract the zip file
with zipfile.ZipFile(files, 'r') as zip_ref:
    zip_ref.extractall(extract_path)  # Extract to the current working directory instead of '/content'
    # Using 'with' statement automatically closes the zip file

# %% [markdown]
# # 3. Data Understanding

# %% [markdown]
# ### 3.1 Read data with pandas DataFrame

# %%
df = pd.read_csv(files)
df.head()
# Out:
#            Game Title  User Rating Age Group Targeted  Price     Platform  \
# 0  Grand Theft Auto V         36.4           All Ages  41.41           PC
# 1          The Sims 4         38.3             Adults  57.56           PC
# 2           Minecraft         26.8              Teens  44.93           PC
# 3   Bioshock Infinite         38.4           All Ages  48.29       Mobile
# 4     Half-Life: Alyx         30.1             Adults  55.49  PlayStation
#
#   Requires Special Device   Developer        Publisher  Release Year  \
# 0                      No  Game Freak       Innersloth          2015
# 1                      No    Nintendo  Electronic Arts          2015
# 2                     Yes      Bungie           Capcom          2012
# 3                     Yes  Game Freak         Nintendo          2015
# 4                     Yes  Game Freak       Epic Games          2022
#
#        Genre Multiplayer  Game Length (Hours) Graphics Quality  \
# 0  Adventure          No                 55.3           Medium
# 1    Shooter         Yes                 34.6              Low
# 2  Adventure         Yes                 13.9              Low
# 3     Sports          No                 41.9           Medium
# 4        RPG         Yes                 13.2             High
#
#   Soundtrack Quality Story Quality  \
# 0            Average          Poor
# 1               Poor          Poor
# 2               Good       Average
# 3               Good     Excellent
# 4               Poor          Good
#
#                                 User Review Text Game Mode  \
# 0                 Solid game, but too many bugs.   Offline
# 1                 Solid game, but too many bugs.   Offline
# 2  Great game, but the graphics could be better.   Offline
# 3  Solid game, but the graphics could be better.    Online
# 4                 Great game, but too many bugs.   Offline
#
#    Min Number of Players
# 0                      1
# 1                      3
# 2                      5
# 3                      4
# 4                      1

# %%
df.shape
# Out:
# (47774, 18)

# %%
# Check dataset information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47774 entries, 0 to 47773
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Game Title               47774 non-null  object
#  1   User Rating              47774 non-null  float64
#  2   Age Group Targeted       47774 non-null  object
#  3   Price                    47774 non-null  float64
#  4   Platform                 47774 non-null  object
#  5   Requires Special Device  47774 non-null  object
#  6   Developer                47774 non-null  object
#  7   Publisher                47774 non-null  object
#  8   Release Year             47774 non-null  int64
#  9   Genre                    47774 non-null  object
#  10  Multiplayer              47774 non-null  object
#  11  Game Length (Hours)      47774 non-null  float64
#  12  Graphics Quality         47774 non-null  object
#  13  Soundtrack Quality       47774 non-null  object
#  14  Story Quality            47774 non-null  object
#  15  User Review Text         47774 non-null  object
#  16  Game Mode                47774 non-null  object
#  17  Min Number of Players    47774 non-null  int64
# dtypes: float64(3), int64(2), object(13)
# memory usage: 6.6+ MB

# %%
df.isna().sum()
# Out:
# Game Title                 0
# User Rating                0
# Age Group Targeted         0
# Price                      0
# Platform                   0
# Requires Special Device    0
# Developer                  0
# Publisher                  0
# Release Year               0
# Genre                      0
# Multiplayer                0
# Game Length (Hours)        0
# Graphics Quality           0
# Soundtrack Quality         0
# Story Quality              0
# User Review Text           0
# Game Mode                  0
# Min Number of Players      0
# dtype: int64

# %%
# Describe dataset column
df.describe()
# Out:
#         User Rating         Price  Release Year  Game Length (Hours)  \
# count  47774.000000  47774.000000  47774.000000         47774.000000
# mean      29.719329     39.951371   2016.480952            32.481672
# std        7.550131     11.520342      4.027276            15.872508
# min       10.100000     19.990000   2010.000000             5.000000
# 25%       24.300000     29.990000   2013.000000            18.800000
# 50%       29.700000     39.845000   2016.000000            32.500000
# 75%       35.100000     49.957500   2020.000000            46.300000
# max       49.500000     59.990000   2023.000000            60.000000
#
#        Min Number of Players
# count           47774.000000
# mean                5.116758
# std                 2.769521
# min                 1.000000
# 25%                 3.000000
# 50%                 5.000000
# 75%                 7.000000
# max                10.000000

# %% [markdown]
# # 4. Data Preparation

# %% [markdown]
# ### 4.1 Drop column that have missing values and unused

# %%
df.drop(['Requires Special Device', 'Publisher'], axis=1, inplace=True)

# %% [markdown]
# ### 4.2 Clean every columns of the data

# %% [markdown]
# #### 4.2.1 Loop through colums for missing values

# %%
# Check missing values
cols = df.columns.tolist()
for col in cols:
    if(df[col].isna().sum() == 0):
      print("There is no empty data in the % s column" % col)
    else:
      print("Missing value detected in % s column" % col)
# Out:
# There is no empty data in the Game Title column
# There is no empty data in the User Rating column
# There is no empty data in the Age Group Targeted column
# There is no empty data in the Price column
# There is no empty data in the Platform column
# There is no empty data in the Developer column
# There is no empty data in the Release Year column
# There is no empty data in the Genre column
# There is no empty data in the Multiplayer column
# There is no empty data in the Game Length (Hours) column
# There is no empty data in the Graphics Quality column
# There is no empty data in the Soundtrack Quality column
# There is no empty data in the Story Quality column
# There is no empty data in the User Review Text column
# There is no empty data in the Game Mode column
# There is no empty data in the Min Number of Players column

# %% [markdown]
# #### 4.2.2 Platform Column

# %%
# use collections Counter to check the sum of each platform column element
platform_counter = Counter(df['Platform'])
platform_counter
# Out:
# Counter({'PlayStation': 9633,
#          'PC': 9599,
#          'Nintendo Switch': 9596,
#          'Mobile': 9589,
#          'Xbox': 9357})

# %%
# Check unique element
df['Platform'].unique()
# Out:
# array(['PC', 'Mobile', 'PlayStation', 'Xbox', 'Nintendo Switch'],
#       dtype=object)

# %% [markdown]
# #### 4.2.3 Genre Column

# %%
# Check missing value
df['Genre'].isna().sum()
# Out:
# np.int64(0)

# %%
# Check unique element
df['Genre'].unique()
# Out:
# array(['Adventure', 'Shooter', 'Sports', 'RPG', 'Simulation', 'Strategy',
#        'Fighting', 'Action', 'Party', 'Puzzle'], dtype=object)

# %%
# check dataset information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47774 entries, 0 to 47773
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Game Title             47774 non-null  object
#  1   User Rating            47774 non-null  float64
#  2   Age Group Targeted     47774 non-null  object
#  3   Price                  47774 non-null  float64
#  4   Platform               47774 non-null  object
#  5   Developer              47774 non-null  object
#  6   Release Year           47774 non-null  int64
#  7   Genre                  47774 non-null  object
#  8   Multiplayer            47774 non-null  object
#  9   Game Length (Hours)    47774 non-null  float64
#  10  Graphics Quality       47774 non-null  object
#  11  Soundtrack Quality     47774 non-null  object
#  12  Story Quality          47774 non-null  object
#  13  User Review Text       47774 non-null  object
#  14  Game Mode              47774 non-null  object
#  15  Min Number of Players  47774 non-null  int64
# dtypes: float64(3), int64(2), object(11)
# memory usage: 5.8+ MB

# %% [markdown]
# #### 4.2.4 Publisher Column

# %%
# Check unique element
df['Developer'].unique()
# Out:
# array(['Game Freak', 'Nintendo', 'Bungie', 'Capcom', 'Epic Games',
#        'CD Projekt Red', 'EA Sports', 'Rockstar Games', 'Innersloth',
#        'Valve'], dtype=object)

# %%
# Check the unknown element
df[df['Developer'] == 'Unknown']
# Out:
# Empty DataFrame
# Columns: [Game Title, User Rating, Age Group Targeted, Price, Platform, Developer, Release Year, Genre, Multiplayer, Game Length (Hours), Graphics Quality, Soundtrack Quality, Story Quality, User Review Text, Game Mode, Min Number of Players]
# Index: []

# %% [markdown]
# #### 4.2.5 Release Year

# %%
# change column type to string because it is categorical
df['Release Year'] = df['Release Year'].astype('str')

# %% [markdown]
# #### 4.2.6 User Rating

# %%
# shift decimal for rating value
df['User Rating'] = df['User Rating'] / 10

# %%
df.head()
# Out:
#            Game Title  User Rating Age Group Targeted  Price     Platform  \
# 0  Grand Theft Auto V        0.364           All Ages  41.41           PC
# 1          The Sims 4        0.383             Adults  57.56           PC
# 2           Minecraft        0.268              Teens  44.93           PC
# 3   Bioshock Infinite        0.384           All Ages  48.29       Mobile
# 4     Half-Life: Alyx        0.301             Adults  55.49  PlayStation
#
#     Developer Release Year      Genre Multiplayer  Game Length (Hours)  \
# 0  Game Freak         2015  Adventure          No                 55.3
# 1    Nintendo         2015    Shooter         Yes                 34.6
# 2      Bungie         2012  Adventure         Yes                 13.9
# 3  Game Freak         2015     Sports          No                 41.9
# 4  Game Freak         2022        RPG         Yes                 13.2
#
#   Graphics Quality Soundtrack Quality Story Quality  \
# 0           Medium            Average          Poor
# 1              Low               Poor          Poor
# 2              Low               Good       Average
# 3           Medium               Good     Excellent
# 4             High               Poor          Good
#
#                                 User Review Text Game Mode  \
# 0                 Solid game, but too many bugs.   Offline
# 1                 Solid game, but too many bugs.   Offline
# 2  Great game, but the graphics could be better.   Offline
# 3  Solid game, but the graphics could be better.    Online
# 4                 Great game, but too many bugs.   Offline
#
#    Min Number of Players
# 0                      1
# 1                      3
# 2                      5
# 3                      4
# 4                      1

# %%
# Describe dataset column
df.describe()
# Out:
#         User Rating         Price  Release Year  Game Length (Hours)  \
# count  47774.000000  47774.000000  47774.000000         47774.000000
# mean       2.971933     39.951371   2016.480952            32.481672
# std        0.755013     11.520342      4.027276            15.872508
# min        1.010000     19.990000   2010.000000             5.000000
# 25%        2.430000     29.990000   2013.000000            18.800000
# 50%        2.970000     39.845000   2016.000000            32.500000
# 75%        3.510000     49.957500   2020.000000            46.300000
# max        4.950000     59.990000   2023.000000            60.000000
#
#        Min Number of Players
# count           47774.000000
# mean                5.116758
# std                 2.769521
# min                 1.000000
# 25%                 3.000000
# 50%                 5.000000
# 75%                 7.000000
# max                10.000000

# %%
# check missing value of the whole data
df.isna().sum()
# Out:
# Game Title               0
# User Rating              0
# Age Group Targeted       0
# Price                    0
# Platform                 0
# Developer                0
# Release Year             0
# Genre                    0
# Multiplayer              0
# Game Length (Hours)      0
# Graphics Quality         0
# Soundtrack Quality       0
# Story Quality            0
# User Review Text         0
# Game Mode                0
# Min Number of Players    0
# dtype: int64

# %%
# check that all missing values in the dataset have been removed
if df.isna().sum().sum() == 0:
  print('Dataset cleaned')
else:
  print('Missing value detected')
# Out:
# Dataset cleaned
